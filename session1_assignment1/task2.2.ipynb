# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i=[1,2,3,4,5]
j =[4,3,2,1]

for value in i:
    print('* ' *value)
    if value==5:
        for value in j:
            print('* ' *value)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
